# %% [markdown]
# <a href="https://colab.research.google.com/github/sreedhar1001/datagit/blob/main/Generate_Blog_posts_With_GPT2_and_Hugging_face_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-large')
model=GPT2LMHeadModel.from_pretrained('gpt2-large',pad_token_id=tokenizer.eos_token_id)
# Out:
# Loading weights:   0%|          | 0/436 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2-large
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...35}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
sentence='I love icream'
input_ids=tokenizer.encode(sentence,return_tensors='pt')

# %%
input_ids
# Out:
# tensor([[   40,  1842, 14158,  1476]])

# %%
tokenizer.decode(input_ids[0][2])
# Out:
# ' ic'

# %%
output=model.generate(input_ids,max_length=500,num_beams=5,no_repeat_ngram_size=3,early_stopping=True)

# %%
tokenizer.decode(output[0],skip_special_tokens=True)
# Out:
# 'I love icream. I love ice cream. I don\'t know what it is about it, but I love it. It\'s the best thing in the world.\n\nI\'m not a big fan of ice cream, and I\'m not going to pretend to be. But I do love it, and it\'s the only thing that makes me feel like I\'m alive. And that\'s what I\'m trying to do with this book. I want people to feel like they\'re alive, and that\'s why I\'m writing it. I wanted to write a book that would make you feel like you\'re alive. I didn\'t want to write something that was going to make you think, "Oh, I\'m going to die." That\'s not what I was going for. I just wanted to make people feel alive. That\'s what this book is about. I think it\'s going to be a great book, and people are going to love it and they\'re going to want to read it.'

# %%
text = tokenizer.decode(output[0],skip_special_tokens=True)
with open("blogpost.txt","w") as f:
  f.write(text)
