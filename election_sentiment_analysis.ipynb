# %%
import pandas as pd
import numpy as np
from textblob import TextBlob 
import plotly.express as px
import plotly.graph_objects as go

# %%
pip install textBlob
# Out:
# Requirement already satisfied: textBlob in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (from textBlob) (3.9.2)
# Requirement already satisfied: click in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.9->textBlob) (8.3.1)
# Requirement already satisfied: joblib in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.9->textBlob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.9->textBlob) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.9->textBlob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (from click->nltk>=3.9->textBlob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (6.5.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (from plotly) (2.14.0)
# Requirement already satisfied: packaging in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install px
# Out:
# Requirement already satisfied: px in c:\users\supriya\appdata\local\programs\python\python311\lib\site-packages (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install go
# Out:
# Collecting go
#   Using cached go-1.2.1.zip (20 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [23 lines of output]
#       Traceback (most recent call last):
#         File "c:\Users\supriya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "c:\Users\supriya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "c:\Users\supriya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\supriya\AppData\Local\Temp\pip-build-env-gsgiufxn\overlay\Lib\site-packages\setuptools\build_meta.py", line 331, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\supriya\AppData\Local\Temp\pip-build-env-gsgiufxn\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\supriya\AppData\Local\Temp\pip-build-env-gsgiufxn\overlay\Lib\site-packages\setuptools\build_meta.py", line 512, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\supriya\AppData\Local\Temp\pip-build-env-gsgiufxn\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 19, in <module>
#         File "C:\Users\supriya\AppData\Local\Temp\pip-install-m5comht0\go_4f509fdefb25495f8950daad64330190\lib\go.py", line 389
#           print "* * *"
#           ^^^^^^^^^^^^^
#       SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob 
import plotly.express as px
import plotly.graph_objects as go

# %%
modi=pd.read_csv("C:\\Users\\supriya\\Downloads\\data cleaning\\modi_reviews.csv")
rahul=pd.read_csv("C:\\Users\\supriya\\Downloads\\data cleaning\\rahul_reviews.csv")

# %%
modi.head()
# Out:
#    Unnamed: 0             User  \
# 0           0  advosushildixit
# 1           1           jiaeur
# 2           2    PVenkatGandhi
# 3           3      TheNirbhay1
# 4           4      ShakeChilli
#
#                                                Tweet
# 0  @anjanaomkashyap I am seeing you as future #bj...
# 1  #LokSabhaElections2019 \n23rd May 2019 will re...
# 2  #LokSabhaElections2019 \n23rd May 2019 will re...
# 3  PM Modi creates a new record of being the only...
# 4  @abhijitmajumder Appointment of Successor! \n\...

# %%
rahul.head()
# Out:
#    Unnamed: 0             User  \
# 0           0     Sunnysweet16
# 1           1    drnitinchaube
# 2           2        mrvivek07
# 3           3    JosephPravinP
# 4           4  VandanaMegastar
#
#                                                Tweet
# 0  Wonder why no academic or journalist asks INC ...
# 1  Congrats for the change #australiavotes2019 an...
# 2  Peopel Say “Govt Ne 70 Years Kya kiya”.\nUnse ...
# 3  @ajaymaken @RahulGandhi And as a final touch, ...
# 4  #LokSabhaElections2019 Anyone not having mass ...

# %%
modi["Tweet"][0]
# Out:
# '@anjanaomkashyap I am seeing you as future #bjp spokesperson..\nGood luck. Anjana Om Modi oops Kashyap.\nJournalists like you changed the meaning of journalism. Janta maaf nai karege'

# %%
modi["Tweet"][1]
# Out:
# '#LokSabhaElections2019 \n23rd May 2019 will reveal ..\nEven ECISVEEP could not help Modi Win 🤔\n\nJanatab Mann Banaata Hai to\nChupke Se Be Jor Se Tappad Deta Hai ..'

# %%
rahul["Tweet"][0]
# Out:
# 'Wonder why no academic or journalist asks INC India and Rahul Gandhi a simple question-what danger was there to the original constitution that they changed it more than 100 times in the course of 55 yrs they ruled? #LokSabhaElections2019'

# %%
TextBlob(modi["Tweet"][0]).sentiment
# Out:
# Sentiment(polarity=0.35, subjectivity=0.36250000000000004)

# %%
def  polarity(review):
    return TextBlob(review).sentiment.polarity
polarity("i love india")
# Out:
# 0.5

# %%
print(polarity("i hate india"))
# Out:
# -0.8

# %%
TextBlob("i love my india").sentiment.polarity
# Out:
# 0.5

# %%
modi["polarity"]=modi["Tweet"].apply(polarity)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 modi["polarity"]=modi["Tweet"].apply(polarity)
#
# File c:\Users\supriya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)   4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)   4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# File c:\Users\supriya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\supriya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\supriya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\supriya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[102], line 2, in polarity(review)
#       1 def  polarity(review):
# ----> 2     return TextBlob(review).sentiment.polarity
#
# File c:\Users\supriya\AppData\Local\Programs\Python\Python311\Lib\site-packages\textblob\blob.py:371, in BaseBlob.__init__(self, text, tokenizer, pos_tagger, np_extractor, analyzer, parser, classifier, clean_html)
#     359 def __init__(
#     360     self,
#     361     text,
#    (...)    368     clean_html=False,
#     369 ):
#     370     if not isinstance(text, basestring):
# --> 371         raise TypeError(
#     372             "The `text` argument passed to `__init__(text)` "
#     373             f"must be a string, not {type(text)}"
#     374         )
#     375     if clean_html:
#     376         raise NotImplementedError(
#     377             "clean_html has been deprecated. "
#     378             "To remove HTML markup, use BeautifulSoup's "
#     379             "get_text() function"
#     380         )
#
# TypeError: The `text` argument passed to `__init__(text)` must be a string, not <class 'float'>

# %%
modi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25688 entries, 0 to 25687
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25688 non-null  int64
#  1   User        25683 non-null  object
#  2   Tweet       25683 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 602.2+ KB

# %%
modi["Tweet"]=modi["Tweet"].astype(str)
rahul["Tweet"]=rahul["Tweet"].astype(str)

# %%
modi["polarity"]=modi["Tweet"].apply(polarity)
rahul["polarity"]=rahul["Tweet"].apply(polarity)

# %%
modi
# Out:
#        Unnamed: 0             User  \
# 0               0  advosushildixit
# 1               1           jiaeur
# 2               2    PVenkatGandhi
# 3               3      TheNirbhay1
# 4               4      ShakeChilli
# ...           ...              ...
# 25683       25683       shv_indian
# 25684       25684       SONUPINKOO
# 25685       25685       SONUPINKOO
# 25686       25686       SONUPINKOO
# 25687       25687    parthajit0101
#
#                                                    Tweet  polarity
# 0      @anjanaomkashyap I am seeing you as future #bj...  0.350000
# 1      #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000
# 2      #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000
# 3      PM Modi creates a new record of being the only...  0.312121
# 4      @abhijitmajumder Appointment of Successor! \n\...  0.098788
# ...                                                  ...       ...
# 25683  #1DDrive #ModiSpeaksToNews18 #LokSabhaElection...  0.000000
# 25684  I am seriously worried about future of Indian ...  0.209524
# 25685  If @narendramodi is so Bad then Why does @INCI... -0.700000
# 25686  On this 23rd March (Pakistan Day), I Urge all ...  0.000000
# 25687  @timesofindia #ArvindKejriwal, #AAP sirji pls ... -0.213542
#
# [25688 rows x 4 columns]

# %%
rahul
# Out:
#        Unnamed: 0             User  \
# 0               0     Sunnysweet16
# 1               1    drnitinchaube
# 2               2        mrvivek07
# 3               3    JosephPravinP
# 4               4  VandanaMegastar
# ...           ...              ...
# 14256       14256         SunjayJK
# 14257       14257         SunjayJK
# 14258       14258       RAMANKAIRA
# 14259       14259       RAMANKAIRA
# 14260       14260       RAMANKAIRA
#
#                                                    Tweet  polarity
# 0      Wonder why no academic or journalist asks INC ...  0.218750
# 1      Congrats for the change #australiavotes2019 an...  0.000000
# 2      Peopel Say “Govt Ne 70 Years Kya kiya”.\nUnse ...  0.000000
# 3      @ajaymaken @RahulGandhi And as a final touch, ...  0.320000
# 4      #LokSabhaElections2019 Anyone not having mass ... -0.166667
# ...                                                  ...       ...
# 14256  @quizzicalguy In this #LokSabhaElections2019, ...  0.000000
# 14257  @AnumaVidisha @RahulGandhi @ArvindKejriwal whe... -0.500000
# 14258  @sherryontopp Early morning #political move af...  0.080000
# 14259  @mayankgandhi04 @mallesh_2004 Early morning #p...  0.080000
# 14260  @DrKumarVishwas Early morning #political move ...  0.080000
#
# [14261 rows x 4 columns]

# %%
modi["Label"]=np.where(modi["polarity"]>0,"positive","negative")
modi["Label"][modi["polarity"]==0]="Neutral"
# Out:
# C:\Users\supriya\AppData\Local\Temp\ipykernel_16516\3703168912.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   modi["Label"][modi["polarity"]==0]="Neutral"
# C:\Users\supriya\AppData\Local\Temp\ipykernel_16516\3703168912.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modi["Label"][modi["polarity"]==0]="Neutral"

# %%
# Out:
#        Unnamed: 0             User  \
# 0               0  advosushildixit
# 1               1           jiaeur
# 2               2    PVenkatGandhi
# 3               3      TheNirbhay1
# 4               4      ShakeChilli
# ...           ...              ...
# 25683       25683       shv_indian
# 25684       25684       SONUPINKOO
# 25685       25685       SONUPINKOO
# 25686       25686       SONUPINKOO
# 25687       25687    parthajit0101
#
#                                                    Tweet  polarity     Label
# 0      @anjanaomkashyap I am seeing you as future #bj...  0.350000  positive
# 1      #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000  positive
# 2      #LokSabhaElections2019 \n23rd May 2019 will re...  0.800000  positive
# 3      PM Modi creates a new record of being the only...  0.312121  positive
# 4      @abhijitmajumder Appointment of Successor! \n\...  0.098788  positive
# ...                                                  ...       ...       ...
# 25683  #1DDrive #ModiSpeaksToNews18 #LokSabhaElection...  0.000000   Neutral
# 25684  I am seriously worried about future of Indian ...  0.209524  positive
# 25685  If @narendramodi is so Bad then Why does @INCI... -0.700000  negative
# 25686  On this 23rd March (Pakistan Day), I Urge all ...  0.000000   Neutral
# 25687  @timesofindia #ArvindKejriwal, #AAP sirji pls ... -0.213542  negative
#
# [25688 rows x 5 columns]

# %%
rahul["Label"]=np.where(rahul["polarity"]>0,"positive","negative")
rahul["Label"][rahul["polarity"] == 0] = "Neutral"
# Out:
# C:\Users\supriya\AppData\Local\Temp\ipykernel_16516\1093480738.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   rahul["Label"][rahul["polarity"] == 0] = "Neutral"
# C:\Users\supriya\AppData\Local\Temp\ipykernel_16516\1093480738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rahul["Label"][rahul["polarity"] == 0] = "Neutral"

# %%
neutral_modi=modi[modi["polarity"]==0.0000]
remove_neutral_modi=modi["polarity"].isin(neutral_modi["polarity"])
modi.drop(modi[remove_neutral_modi].index,inplace=True)

# %%
neutral_rahul=rahul[rahul["polarity"]==0.0000]
remove_neutral_rahul=rahul["polarity"].isin(neutral_rahul["polarity"])
rahul.drop(rahul[remove_neutral_rahul].index,inplace=True)

# %%
print(neutral_modi.shape)
# Out:
# (8207, 5)

# %%
print(neutral_rahul.shape)
# Out:
# (4453, 5)

# %%
np.random.seed(10)
remove_n=8481
drop_indices=np.random.choice(modi.index ,remove_n,replace=False)
df_modi=modi.drop(drop_indices)

# %%
np.random.seed(10)
remove_n=367
drop_indices=np.random.choice(rahul.index ,remove_n,replace=False)
df_rahul=rahul.drop(drop_indices)

# %%
print(df_modi.shape)
# Out:
# (9000, 5)

# %%
print(df_rahul.shape)
# Out:
# (17114, 5)

# %%
#prediction
modi_count=df_modi.groupby("Label").count()

modi_count
neg_modi=(modi_count["polarity"][0]/1000)*100
pos_modi=(modi_count["polarity"][1]/1000)*100
# Out:
# C:\Users\supriya\AppData\Local\Temp\ipykernel_16516\4212235499.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   neg_modi=(modi_count["polarity"][0]/1000)*100
# C:\Users\supriya\AppData\Local\Temp\ipykernel_16516\4212235499.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pos_modi=(modi_count["polarity"][1]/1000)*100

# %%
rahul_count=df_rahul.groupby("Label").count()

rahul_count
neg_rahul=(rahul_count["polarity"][0]/1000)*100
pos_rahul=(rahul_count["polarity"][1]/1000)*100
# Out:
# C:\Users\supriya\AppData\Local\Temp\ipykernel_16516\573046038.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   neg_rahul=(rahul_count["polarity"][0]/1000)*100
# C:\Users\supriya\AppData\Local\Temp\ipykernel_16516\573046038.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pos_rahul=(rahul_count["polarity"][1]/1000)*100

# %%
#visualization
politians=["modi","rahul"]
neg_list=[neg_modi,neg_rahul]
pos_list=[pos_modi,pos_rahul]
fig=go.Figure(data=[
    go.Bar(name="negative",x=politians,y=neg_list),
    go.Bar(name="positive",x=politians,y=pos_list),
]
)
fig.update_layout(barmode="group")
fig.show()
